# %% [markdown]
# # JPEG Decode Python Sample
# ## Batch

# %%
import torch
import pyRocJpegDecode.decoder as jdec
import numpy as np
from PIL import Image
from IPython.display import display
import cv2

# %% [markdown]
# Load images

# %%
image_paths = ["/opt/rocm/share/rocjpeg/images/mug_400.jpg", "/opt/rocm/share/rocjpeg/images/mug_420.jpg", "/opt/rocm/share/rocjpeg/images/mug_422.jpg"]
batch_size = len(image_paths)

# %% [markdown]
# Create decoder

# %%
device_id = 0
backend = 0
decoder = jdec.decoder(device_id, backend)

# %% [markdown]
# Decode data

# %%
data_list = []
for p in image_paths:
    with open(p, 'rb') as in_file:
        data = in_file.read()
        data_list.append(data)
        
image_list = decoder.decode(data_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3054101/2077272876.py in <module>
#       5         data_list.append(data)
#       6
# ----> 7 image_list = decoder.decode(data_list)
#
# NameError: name 'decoder' is not defined

# %% [markdown]
# Decode files

# %%
images = decoder.decode(image_paths)
